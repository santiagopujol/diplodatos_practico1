# %% [markdown]
# <center>
# <h4>Universidad Nacional de Córdoba - Facultad de Matemática, Astronomía, Física y Computación</h4>
# <h3>Diplomatura en Ciencia de Datos, Aprendizaje Automático y sus Aplicaciones</h3>
# </center>

# %% [markdown]
# <h1> Práctico I - Estadística </h1>
# <h3> Análisis y Visualización de Datos - 2019 </h3>
#
# Durante este práctico vamos a trabajar sobre el dataset [Human Freedom Index 2018](https://www.cato.org/human-freedom-index-new) de el instituto Cato. Este índice mide en detalle lo que entendemos como libertad, utilizando 79 indicadores de libertad personal y económica en distintos aspectos, hasta obtener un hermoso numerito del 1 al 10. Usaremos una [versión ya limpia del dataset](https://www.kaggle.com/gsutters/the-human-freedom-index/home) que pueden descargar desde Kaggle.
#
# Las variables más importantes sobre las que trabaja el dataset son:
#
# * Rule of Law
# * Security and Safety
# * Movement
# * Religion
# * Association, Assembly, and Civil Society
# * Expression and Information
# * Identity and Relationships
# * Size of Government
# * Legal System and Property Rights
# * Access to Sound Money
# * Freedom to Trade Internationally
# * Regulation of Credit, Labor, and Business
#
# Nosotros centrarermos nuestro análisis en variables relacionadas a *Identity and Relationships* en paises de Latinoamérica, y los compararemos con las estadísticas globales. La pregunta a responder es simple: **¿Qué niveles de libertad se viven en Latinoamérica, especificamente en cuanto libertades de indentidad?**. Sin embargo, para hacer un análisis de los datos tenemos que platear también estas sub preguntas:
#
# 1. ¿Qué significa tener un puntaje de 4.5? Hay que poner los puntajes de la región en contexto con los datos del resto del mundo.
# 2. ¿Cuál es la tendencia a lo largo de los años? ¿Estamos mejorando, empeorando?
# 3. En este estudio, la libertad se mide con dos estimadores principales: *hf_score* que hace referencia a Human Freedom, y *ef_score* que hace referencia a Economic Freedom. Estos dos estimadores, ¿se relacionan de la misma manera con la libertad de identidad?
#
# Inicialmente, en toda exploración de datos tenemos muy poca información a priori sobre el significado de los datos y tenemos que empezar por comprenderlos. Les proponemos los siguientes ejercicios como guía para comenzar esta exploración.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy
import pandas
import seaborn
import scipy.stats as ss

# %%
BLUE='#35A7FF'
RED='#FF5964'
GREEN='#6BF178'
YELLOW='#FFE74C'

# %%
# Con esto hacemos los gráficos más grandes, adecuados para el proyector.
seaborn.set_context(context='talk', font_scale=1.2)

# %%
seaborn.__version__
# Out:
# '0.9.0'

# %%
dataset = pandas.read_csv('hfi_cc_2018.csv')
dataset.shape
# Out:
# (1458, 123)

# %%
dataset.columns  # Way too many columns!
# Out:
# Index(['year', 'ISO_code', 'countries', 'region', 'pf_rol_procedural',
#        'pf_rol_civil', 'pf_rol_criminal', 'pf_rol', 'pf_ss_homicide',
#        'pf_ss_disappearances_disap',
#        ...
#        'ef_regulation_business_bribes', 'ef_regulation_business_licensing',
#        'ef_regulation_business_compliance', 'ef_regulation_business',
#        'ef_regulation', 'ef_score', 'ef_rank', 'hf_score', 'hf_rank',
#        'hf_quartile'],
#       dtype='object', length=123)

# %% [markdown]
# Por suerte las columnas tienen un prefijo que nos ayuda a identificar a qué sección pertenecen. Nos quedamos sólo con las que comienzan con *pf_indentity*, junto con otras columnas más generales

# %%
important_cols = ['year', 'ISO_code', 'countries', 'region']

important_cols += [col for col in dataset.columns if 'pf_identity' in col]

important_cols += [
    'ef_score', # Economic Freedom (score)
    'ef_rank', # Economic Freedom (rank)
    'hf_score', # Human Freedom (score)
    'hf_rank', # Human Freedom (rank)
]

# %%
dataset[important_cols]
# Out:
#       year ISO_code               countries                         region  \
# 0     2016      ALB                 Albania                 Eastern Europe
# 1     2016      DZA                 Algeria     Middle East & North Africa
# 2     2016      AGO                  Angola             Sub-Saharan Africa
# 3     2016      ARG               Argentina  Latin America & the Caribbean
# 4     2016      ARM                 Armenia        Caucasus & Central Asia
# 5     2016      AUS               Australia                        Oceania
# 6     2016      AUT                 Austria                 Western Europe
# 7     2016      AZE              Azerbaijan        Caucasus & Central Asia
# 8     2016      BHS                 Bahamas  Latin America & the Caribbean
# 9     2016      BHR                 Bahrain     Middle East & North Africa
# 10    2016      BGD              Bangladesh                     South Asia
# 11    2016      BRD                Barbados  Latin America & the Caribbean
# 12    2016      BLR                 Belarus                 Eastern Europe
# 13    2016      BEL                 Belgium                 Western Europe
# 14    2016      BLZ                  Belize  Latin America & the Caribbean
# 15    2016      BEN                   Benin             Sub-Saharan Africa
# 16    2016      BTN                  Bhutan                     South Asia
# 17    2016      BOL                 Bolivia  Latin America & the Caribbean
# 18    2016      BIH  Bosnia and Herzegovina                 Eastern Europe
# 19    2016      BWA                Botswana             Sub-Saharan Africa
# 20    2016      BRA                  Brazil  Latin America & the Caribbean
# 21    2016      BRN       Brunei Darussalam                     South Asia
# 22    2016      BGR                Bulgaria                 Eastern Europe
# 23    2016      BFA            Burkina Faso             Sub-Saharan Africa
# 24    2016      BDI                 Burundi             Sub-Saharan Africa
# 25    2016      KHM                Cambodia                     South Asia
# 26    2016      CMR                Cameroon             Sub-Saharan Africa
# 27    2016      CAN                  Canada                  North America
# 28    2016      CPV              Cape Verde             Sub-Saharan Africa
# 29    2016      CAF       Central Afr. Rep.             Sub-Saharan Africa
# ...    ...      ...                     ...                            ...
# 1428  2008      SVN                Slovenia                 Eastern Europe
# 1429  2008      ZAF            South Africa             Sub-Saharan Africa
# 1430  2008      ESP                   Spain                 Western Europe
# 1431  2008      LKA               Sri Lanka                     South Asia
# 1432  2008      SDN                   Sudan             Sub-Saharan Africa
# 1433  2008      SUR                Suriname  Latin America & the Caribbean
# 1434  2008      SWZ               Swaziland             Sub-Saharan Africa
# 1435  2008      SWE                  Sweden                 Western Europe
# 1436  2008      CHE             Switzerland                 Western Europe
# 1437  2008      SYR                   Syria     Middle East & North Africa
# 1438  2008      TWN                  Taiwan                      East Asia
# 1439  2008      TJK              Tajikistan        Caucasus & Central Asia
# 1440  2008      TZA                Tanzania             Sub-Saharan Africa
# 1441  2008      THA                Thailand                     South Asia
# 1442  2008      TLS             Timor-Leste                     South Asia
# 1443  2008      TGO                    Togo             Sub-Saharan Africa
# 1444  2008      TTO     Trinidad and Tobago  Latin America & the Caribbean
# 1445  2008      TUN                 Tunisia     Middle East & North Africa
# 1446  2008      TUR                  Turkey     Middle East & North Africa
# 1447  2008      UGA                  Uganda             Sub-Saharan Africa
# 1448  2008      UKR                 Ukraine                 Eastern Europe
# 1449  2008      ARE    United Arab Emirates     Middle East & North Africa
# 1450  2008      GBR          United Kingdom                 Western Europe
# 1451  2008      USA           United States                  North America
# 1452  2008      URY                 Uruguay  Latin America & the Caribbean
# 1453  2008      VEN               Venezuela  Latin America & the Caribbean
# 1454  2008      VNM                 Vietnam                     South Asia
# 1455  2008      YEM             Yemen, Rep.     Middle East & North Africa
# 1456  2008      ZMB                  Zambia             Sub-Saharan Africa
# 1457  2008      ZWE                Zimbabwe             Sub-Saharan Africa
#
#       pf_identity_legal  pf_identity_parental_marriage  \
# 0                   0.0                           10.0
# 1                   NaN                            0.0
# 2                  10.0                           10.0
# 3                  10.0                           10.0
# 4                   7.0                           10.0
# 5                   7.0                           10.0
# 6                  10.0                           10.0
# 7                   0.0                           10.0
# 8                   NaN                           10.0
# 9                   NaN                            0.0
# 10                  0.0                            0.0
# 11                  NaN                           10.0
# 12                  7.0                           10.0
# 13                  7.0                           10.0
# 14                  NaN                           10.0
# 15                  NaN                           10.0
# 16                  0.0                            NaN
# 17                 10.0                           10.0
# 18                  7.0                           10.0
# 19                  7.0                            5.0
# 20                  0.0                           10.0
# 21                  0.0                            0.0
# 22                  7.0                           10.0
# 23                  NaN                           10.0
# 24                  NaN                            5.0
# 25                  NaN                           10.0
# 26                  NaN                           10.0
# 27                  7.0                           10.0
# 28                  NaN                            NaN
# 29                  NaN                            5.0
# ...                 ...                            ...
# 1428                NaN                            NaN
# 1429                NaN                            NaN
# 1430                NaN                            NaN
# 1431                NaN                            NaN
# 1432                NaN                            NaN
# 1433                NaN                            NaN
# 1434                NaN                            NaN
# 1435                NaN                            NaN
# 1436                NaN                            NaN
# 1437                NaN                            NaN
# 1438                NaN                            NaN
# 1439                NaN                            NaN
# 1440                NaN                            NaN
# 1441                NaN                            NaN
# 1442                NaN                            NaN
# 1443                NaN                            NaN
# 1444                NaN                            NaN
# 1445                NaN                            NaN
# 1446                NaN                            NaN
# 1447                NaN                            NaN
# 1448                NaN                            NaN
# 1449                NaN                            NaN
# 1450                NaN                            NaN
# 1451                NaN                            NaN
# 1452                NaN                            NaN
# 1453                NaN                            NaN
# 1454                NaN                            NaN
# 1455                NaN                            NaN
# 1456                NaN                            NaN
# 1457                NaN                            NaN
#
#       pf_identity_parental_divorce  pf_identity_parental  \
# 0                             10.0                  10.0
# 1                              5.0                   2.5
# 2                             10.0                  10.0
# 3                             10.0                  10.0
# 4                             10.0                  10.0
# 5                             10.0                  10.0
# 6                             10.0                  10.0
# 7                             10.0                  10.0
# 8                             10.0                  10.0
# 9                              0.0                   0.0
# 10                             0.0                   0.0
# 11                            10.0                  10.0
# 12                            10.0                  10.0
# 13                            10.0                  10.0
# 14                            10.0                  10.0
# 15                            10.0                  10.0
# 16                            10.0                  10.0
# 17                            10.0                  10.0
# 18                            10.0                  10.0
# 19                             5.0                   5.0
# 20                            10.0                  10.0
# 21                             0.0                   0.0
# 22                            10.0                  10.0
# 23                            10.0                  10.0
# 24                            10.0                   7.5
# 25                            10.0                  10.0
# 26                            10.0                  10.0
# 27                            10.0                  10.0
# 28                             NaN                   NaN
# 29                             5.0                   5.0
# ...                            ...                   ...
# 1428                           NaN                  10.0
# 1429                           NaN                   5.0
# 1430                           NaN                  10.0
# 1431                           NaN                   5.0
# 1432                           NaN                   NaN
# 1433                           NaN                   NaN
# 1434                           NaN                   NaN
# 1435                           NaN                  10.0
# 1436                           NaN                  10.0
# 1437                           NaN                   5.0
# 1438                           NaN                  10.0
# 1439                           NaN                   NaN
# 1440                           NaN                   5.0
# 1441                           NaN                  10.0
# 1442                           NaN                   NaN
# 1443                           NaN                   5.0
# 1444                           NaN                  10.0
# 1445                           NaN                  10.0
# 1446                           NaN                  10.0
# 1447                           NaN                   5.0
# 1448                           NaN                  10.0
# 1449                           NaN                   0.0
# 1450                           NaN                  10.0
# 1451                           NaN                  10.0
# 1452                           NaN                  10.0
# 1453                           NaN                  10.0
# 1454                           NaN                  10.0
# 1455                           NaN                   NaN
# 1456                           NaN                   0.0
# 1457                           NaN                   5.0
#
#       pf_identity_sex_male  pf_identity_sex_female  pf_identity_sex  \
# 0                     10.0                    10.0             10.0
# 1                      0.0                     0.0              0.0
# 2                      0.0                     0.0              0.0
# 3                     10.0                    10.0             10.0
# 4                     10.0                    10.0             10.0
# 5                     10.0                    10.0             10.0
# 6                     10.0                    10.0             10.0
# 7                     10.0                    10.0             10.0
# 8                     10.0                    10.0             10.0
# 9                     10.0                    10.0             10.0
# 10                     0.0                    10.0              5.0
# 11                     0.0                     0.0              0.0
# 12                    10.0                    10.0             10.0
# 13                    10.0                    10.0             10.0
# 14                    10.0                    10.0             10.0
# 15                    10.0                    10.0             10.0
# 16                     0.0                     0.0              0.0
# 17                    10.0                    10.0             10.0
# 18                    10.0                    10.0             10.0
# 19                     0.0                     0.0              0.0
# 20                    10.0                    10.0             10.0
# 21                     0.0                    10.0              5.0
# 22                    10.0                    10.0             10.0
# 23                    10.0                    10.0             10.0
# 24                     0.0                     0.0              0.0
# 25                    10.0                    10.0             10.0
# 26                     0.0                     0.0              0.0
# 27                    10.0                    10.0             10.0
# 28                    10.0                    10.0             10.0
# 29                    10.0                    10.0             10.0
# ...                    ...                     ...              ...
# 1428                  10.0                    10.0             10.0
# 1429                  10.0                    10.0             10.0
# 1430                  10.0                    10.0             10.0
# 1431                   0.0                     0.0              0.0
# 1432                   NaN                     NaN              NaN
# 1433                   NaN                     NaN              NaN
# 1434                   NaN                     NaN              NaN
# 1435                  10.0                    10.0             10.0
# 1436                  10.0                    10.0             10.0
# 1437                   0.0                     0.0              0.0
# 1438                  10.0                    10.0             10.0
# 1439                   NaN                     NaN              NaN
# 1440                   0.0                     0.0              0.0
# 1441                  10.0                    10.0             10.0
# 1442                   NaN                     NaN              NaN
# 1443                   0.0                     0.0              0.0
# 1444                   0.0                     0.0              0.0
# 1445                   0.0                     0.0              0.0
# 1446                  10.0                    10.0             10.0
# 1447                   0.0                     0.0              0.0
# 1448                  10.0                    10.0             10.0
# 1449                   0.0                     0.0              0.0
# 1450                  10.0                    10.0             10.0
# 1451                  10.0                    10.0             10.0
# 1452                  10.0                    10.0             10.0
# 1453                  10.0                    10.0             10.0
# 1454                  10.0                    10.0             10.0
# 1455                   NaN                     NaN              NaN
# 1456                   0.0                    10.0              5.0
# 1457                   0.0                    10.0              5.0
#
#       pf_identity_divorce  pf_identity  ef_score  ef_rank  hf_score  hf_rank
# 0                     5.0     6.250000      7.54     34.0  7.568140     48.0
# 1                     0.0     0.833333      4.99    159.0  5.135886    155.0
# 2                    10.0     7.500000      5.17    155.0  5.640662    142.0
# 3                    10.0    10.000000      4.84    160.0  6.469848    107.0
# 4                     5.0     8.000000      7.57     29.0  7.241402     57.0
# 5                    10.0     9.250000      7.98     10.0  8.582219      4.0
# 6                    10.0    10.000000      7.58     27.0  8.413474     16.0
# 7                     5.0     6.250000      6.49    106.0  6.083277    130.0
# 8                     NaN    10.000000      7.34     49.0  7.397269     50.0
# 9                     0.0     3.333333      7.56     30.0  6.848035     75.0
# 10                    0.0     1.250000      6.30    120.0  5.801300    138.0
# 11                    NaN     5.000000      6.43    111.0  7.068447     67.0
# 12                    5.0     8.000000      6.23    123.0  6.144514    128.0
# 13                   10.0     9.250000      7.32     52.0  8.153589     27.0
# 14                    NaN    10.000000      6.86     83.0  7.145432     64.0
# 15                   10.0    10.000000      5.98    134.0  6.738488     90.0
# 16                    5.0     3.750000      7.02     73.0  6.810486     83.0
# 17                   10.0    10.000000      6.23    123.0  6.718385     92.0
# 18                   10.0     9.250000      6.60     98.0  7.230724     59.0
# 19                    5.0     4.250000      7.43     44.0  7.153167     64.0
# 20                   10.0     7.500000      5.75    144.0  6.207989    123.0
# 21                    NaN     1.666667      6.93     77.0  5.796850    138.0
# 22                   10.0     9.250000      7.41     46.0  7.782770     41.0
# 23                   10.0    10.000000      6.05    129.0  6.752670     88.0
# 24                   10.0     5.833333      5.92    138.0  5.167067    154.0
# 25                    5.0     8.333333      7.17     64.0  7.204224     61.0
# 26                    5.0     5.000000      5.82    141.0  5.575387    144.0
# 27                   10.0     9.250000      7.98     10.0  8.565863      5.0
# 28                    NaN    10.000000      6.68     93.0  7.333292     53.0
# 29                   10.0     8.333333      5.11    156.0  5.287816    152.0
# ...                   ...          ...       ...      ...       ...      ...
# 1428                  NaN    10.000000      7.01     65.0  7.825762     41.0
# 1429                  NaN     7.500000      6.72     81.0  6.762374     86.0
# 1430                  NaN    10.000000      7.37     37.0  8.247249     21.0
# 1431                  NaN     2.500000      6.26     99.0  5.860377    122.0
# 1432                  NaN          NaN       NaN      NaN       NaN      NaN
# 1433                  NaN          NaN       NaN      NaN       NaN      NaN
# 1434                  NaN          NaN       NaN      NaN       NaN      NaN
# 1435                  NaN    10.000000      7.40     36.0  8.452347     11.0
# 1436                  NaN    10.000000      8.24      4.0  8.774437      3.0
# 1437                  NaN     2.500000      5.62    126.0  5.457516    132.0
# 1438                  NaN    10.000000      7.49     31.0  7.792327     43.0
# 1439                  NaN          NaN       NaN      NaN       NaN      NaN
# 1440                  NaN     2.500000      6.20    102.0  6.338606    108.0
# 1441                  NaN    10.000000      6.80     74.0  7.274283     59.0
# 1442                  NaN          NaN       NaN      NaN       NaN      NaN
# 1443                  NaN     2.500000      5.67    124.0  5.763365    124.0
# 1444                  NaN     5.000000      6.74     79.0  6.805600     81.0
# 1445                  NaN     5.000000      6.68     84.0  6.249058    110.0
# 1446                  NaN    10.000000      6.86     68.0  6.918409     76.0
# 1447                  NaN     2.500000      7.21     48.0  6.495271    102.0
# 1448                  NaN    10.000000      5.87    121.0  6.798697     82.0
# 1449                  NaN     0.000000      7.68     17.0  6.784866     85.0
# 1450                  NaN    10.000000      7.99      8.0  8.536421      9.0
# 1451                  NaN    10.000000      8.17      5.0  8.448265     11.0
# 1452                  NaN    10.000000      7.12     58.0  7.947847     37.0
# 1453                  NaN    10.000000      4.22    140.0  5.257879    136.0
# 1454                  NaN    10.000000      6.19    103.0  6.420206    106.0
# 1455                  NaN          NaN       NaN      NaN       NaN      NaN
# 1456                  NaN     2.500000      7.15     57.0  6.647724     95.0
# 1457                  NaN     5.000000      4.55    138.0  4.935571    140.0
#
# [1458 rows x 17 columns]

# %% [markdown]
# ## 1. Estadísticos descriptivos
#
#   1. Para comenzar con un pantallazo de los datos, calcular el rango de las variables.
#   2. Obtener media, mediana y desviación estándar de las variables *pf_identity* y *hf_score* en el mundo y compararla con la de Latinoamérica y el caribe. ¿Tiene sentido calcular la moda?
#   3. ¿Son todos los valores de *pf_identity*  y *hf_score* directamente comparables? ¿Qué otra variable podría influenciarlos?
#   4. ¿Cómo pueden sanearse los valores faltantes?
#   5. ¿Encuentra outliers en estas dos variables? ¿Qué método utiliza para detectarlos? ¿Los outliers, son globales o por grupo? ¿Los eliminaría del conjunto de datos?

# %% [markdown]
# ## 2. Agregación de datos
#
# 1. Grafiquen la media de la variable *pf_identity* y *hf_score* a través de los años.
# 2. Realicen los mismos gráficos, pero separando por regiones (Cada variable en un gráfico distinto, sino no se ve nada). ¿La tendencia observada, es la misma que si no dividimos por regiones?
# 3. Si lo consideran necesario, grafiquen algunos países de Latinoamerica para tratar de explicar la tendencia de la variable *pf_identity* en la región. ¿Cómo seleccionarion los países relevantes a esa tendencia?
#
# Hint: hay un gráfico de seaborn que hace todo por vos!
#
# Sólo por curiosidad, graficar la tendencia de *hf_score* y *ef_score* a través de los años. ¿Tienen alguna hipótesis para este comportamiento?

# %% [markdown]
# ## 3. Distribuciones
#   1. Graficar en un mismo histograma la distribución de la variable *pf_identity* en global, y en Latinoamérica y el caribe. Repetir para la variable *hf_score*. ¿Visualmente, a qué tipo de distribución corresponde cada variable? ¿Es correcto utilizar todos los registros para esas zonas en estos gráficos?
#   2. Realizar una prueba de Kolmogorov-Smirnof para comprobar analíticamente si estas variables responden la distribución propuesta en el ejercicio anterior. Hint: podés usar https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.kstest.html, pero hay que tener en cuenta que si la distribución es "norm", entonces va a comparar los datos con una distribución normal con media 0 y desviación estándar 1. Se puede utilizar la distribución sobre todos los datos o sólo sobre Latinoamérica.
#   3. Realizar un gráfico QQ de las mismas distribuciones. Se puede utilizar a,bas distribuciones sobre todos los datos o sólo sobre Latinoamérica, pero no cruzadas.
#   4. Medir la asimetría (skew) y curtosis de las mismas distribuciones con las que realizó el gráfico anterior. ¿Cómo se relacionan estos estadísticos con la forma del gráfico QQ obtenido previamente? ¿El gráfico QQ provee más información que no esté presente en estos estadísticos?

# %% [markdown]
# ## 4. Correlaciones
#
# En este ejercicio queremos responder a las preguntas
#
# * Las libertades sociales y económicas, ¿van siempre de la mano?
# * ¿Cómo se relacionan ambas con las libertades individuales y respectivas a las relaciones personales?
#
# Para ello, analizaremos las correlaciones entre las variables pf_identity, hf_score y ef_score.
#
# Como pf_indentity contribuye al cálculo de hf_score y ef_score, esperamos hallar algún grado de correlación. Sin embargo, queremos medir qué tanta correlación.
#
# 1. ¿Qué conclusiones puede sacar de un gráfico pairplot de estas tres variables? ¿Es adecuado para los valores de pf_identity? ¿Por qué?
# 2. Graficar la correlación entre pf_identity y hf_score; y entre pf_identity y ef_score. Analizar el resultado, ¿se pueden sacar conclusiones? Tengan en cuenta que como pf_identity es el resultado de un promedio, sólo toma algunos valores. Es, en efecto, discreta.
# 3. Calcular algún coeficiente de correlación adecuado entre los dos pares de variables, dependiendo de la cantidad de datos, el tipo de datos y la distribución de los mismo. Algunas opciones son: coeficiente de pearson, coeficiente de spearman, coeficientes de tau y de kendall. Interpretar los resultados y justificar si las variables están correlacionadas o no.
# 4. [Opcional] Analizar la correlación entre la region y el hf_score (y/o el ef_score); y entre la region y el pf_identity. Considerar que como la variable *region* es ordinal, debe utilizarse algún tipo de test. Explicar cuáles son los requisitos necesarios para la aplicación de ese test. (Si no se cumplieran, se pueden agregar algunos datos para generar más registros)

# %% [markdown]
# ## Respuestas

# %% [markdown]
# ## 1. Estadísticos descriptivos

# %% [markdown]
# ## 1.1
# Para comenzar con un pantallazo de los datos, calcular el rango de las variables.

# %%
for col in dataset.iloc[:,4:]:
    print('Variable ', col, '  Rango = ', dataset[col].max() - dataset[col].min())
# Out:
# Variable  pf_rol_procedural   Rango =  9.7
# Variable  pf_rol_civil   Rango =  8.77353257
# Variable  pf_rol_criminal   Rango =  8.719848041
# Variable  pf_rol   Rango =  8.723093731
# Variable  pf_ss_homicide   Rango =  9.926567913
# Variable  pf_ss_disappearances_disap   Rango =  10.0
# Variable  pf_ss_disappearances_violent   Rango =  10.0
# Variable  pf_ss_disappearances_organized   Rango =  10.0
# Variable  pf_ss_disappearances_fatalities   Rango =  10.0
# Variable  pf_ss_disappearances_injuries   Rango =  10.0
# Variable  pf_ss_disappearances   Rango =  10.0
# Variable  pf_ss_women_fgm   Rango =  9.6
# Variable  pf_ss_women_missing   Rango =  10.0
# Variable  pf_ss_women_inheritance_widows   Rango =  10.0
# Variable  pf_ss_women_inheritance_daughters   Rango =  10.0
# Variable  pf_ss_women_inheritance   Rango =  10.0
# Variable  pf_ss_women   Rango =  10.0
# Variable  pf_ss   Rango =  6.0116724779999995
# Variable  pf_movement_domestic   Rango =  10.0
# Variable  pf_movement_foreign   Rango =  10.0
# Variable  pf_movement_women   Rango =  10.0
# Variable  pf_movement   Rango =  10.0
# Variable  pf_religion_estop_establish   Rango =  10.0
# Variable  pf_religion_estop_operate   Rango =  10.0
# Variable  pf_religion_estop   Rango =  10.0
# Variable  pf_religion_harassment   Rango =  4.755555556
# Variable  pf_religion_restrictions   Rango =  7.5944444440000005
# Variable  pf_religion   Rango =  10.0
# Variable  pf_association_association   Rango =  10.0
# Variable  pf_association_assembly   Rango =  10.0
# Variable  pf_association_political_establish   Rango =  10.0
# Variable  pf_association_political_operate   Rango =  10.0
# Variable  pf_association_political   Rango =  10.0
# Variable  pf_association_prof_establish   Rango =  10.0
# Variable  pf_association_prof_operate   Rango =  10.0
# Variable  pf_association_prof   Rango =  10.0
# Variable  pf_association_sport_establish   Rango =  7.5
# Variable  pf_association_sport_operate   Rango =  10.0
# Variable  pf_association_sport   Rango =  8.75
# Variable  pf_association   Rango =  9.75
# Variable  pf_expression_killed   Rango =  10.0
# Variable  pf_expression_jailed   Rango =  10.0
# Variable  pf_expression_influence   Rango =  9.666666667000001
# Variable  pf_expression_control   Rango =  9.25
# Variable  pf_expression_cable   Rango =  10.0
# Variable  pf_expression_newspapers   Rango =  10.0
# Variable  pf_expression_internet   Rango =  10.0
# Variable  pf_expression   Rango =  9.589285714999999
# Variable  pf_identity_legal   Rango =  10.0
# Variable  pf_identity_parental_marriage   Rango =  10.0
# Variable  pf_identity_parental_divorce   Rango =  10.0
# Variable  pf_identity_parental   Rango =  10.0
# Variable  pf_identity_sex_male   Rango =  10.0
# Variable  pf_identity_sex_female   Rango =  10.0
# Variable  pf_identity_sex   Rango =  10.0
# Variable  pf_identity_divorce   Rango =  10.0
# Variable  pf_identity   Rango =  10.0
# Variable  pf_score   Rango =  7.401598892999999
# Variable  pf_rank   Rango =  161.0
# Variable  ef_government_consumption   Rango =  10.0
# Variable  ef_government_transfers   Rango =  8.059749262
# Variable  ef_government_enterprises   Rango =  10.0
# Variable  ef_government_tax_income   Rango =  10.0
# Variable  ef_government_tax_payroll   Rango =  10.0
# Variable  ef_government_tax   Rango =  10.0
# Variable  ef_government   Rango =  6.353614521000001
# Variable  ef_legal_judicial   Rango =  9.697463512
# Variable  ef_legal_courts   Rango =  8.278197075
# Variable  ef_legal_protection   Rango =  9.288065433
# Variable  ef_legal_military   Rango =  10.0
# Variable  ef_legal_integrity   Rango =  9.833333333
# Variable  ef_legal_enforcement   Rango =  8.105416731
# Variable  ef_legal_restrictions   Rango =  9.981100762999999
# Variable  ef_legal_police   Rango =  9.688242277
# Variable  ef_legal_crime   Rango =  9.67260754
# Variable  ef_legal_gender   Rango =  0.714285714
# Variable  ef_legal   Rango =  7.477457276999999
# Variable  ef_money_growth   Rango =  9.999030735
# Variable  ef_money_sd   Rango =  9.950434267999999
# Variable  ef_money_inflation   Rango =  10.0
# Variable  ef_money_currency   Rango =  10.0
# Variable  ef_money   Rango =  8.974686836
# Variable  ef_trade_tariffs_revenue   Rango =  10.0
# Variable  ef_trade_tariffs_mean   Rango =  7.18
# Variable  ef_trade_tariffs_sd   Rango =  10.0
# Variable  ef_trade_tariffs   Rango =  6.883377778
# Variable  ef_trade_regulatory_nontariff   Rango =  9.188349417000001
# Variable  ef_trade_regulatory_compliance   Rango =  9.963313765
# Variable  ef_trade_regulatory   Rango =  9.728995482
# Variable  ef_trade_black   Rango =  10.0
# Variable  ef_trade_movement_foreign   Rango =  9.252879
# Variable  ef_trade_movement_capital   Rango =  10.0
# Variable  ef_trade_movement_visit   Rango =  10.0
# Variable  ef_trade_movement   Rango =  9.305096948
# Variable  ef_trade   Rango =  7.779841114
# Variable  ef_regulation_credit_ownership   Rango =  10.0
# Variable  ef_regulation_credit_private   Rango =  10.0
# Variable  ef_regulation_credit_interest   Rango =  10.0
# Variable  ef_regulation_credit   Rango =  7.793266374
# Variable  ef_regulation_labor_minwage   Rango =  10.0
# Variable  ef_regulation_labor_firing   Rango =  8.510680848
# Variable  ef_regulation_labor_bargain   Rango =  8.996680475
# Variable  ef_regulation_labor_hours   Rango =  8.0
# Variable  ef_regulation_labor_dismissal   Rango =  10.0
# Variable  ef_regulation_labor_conscription   Rango =  10.0
# Variable  ef_regulation_labor   Rango =  7.625990664
# Variable  ef_regulation_business_adm   Rango =  7.687479655
# Variable  ef_regulation_business_bureaucracy   Rango =  10.0
# Variable  ef_regulation_business_start   Rango =  9.204407926
# Variable  ef_regulation_business_bribes   Rango =  9.623810902999999
# Variable  ef_regulation_business_licensing   Rango =  9.999638041
# Variable  ef_regulation_business_compliance   Rango =  9.865488082
# Variable  ef_regulation_business   Rango =  7.2627586950000005
# Variable  ef_regulation   Rango =  6.9562876650000005
# Variable  ef_score   Rango =  6.31
# Variable  ef_rank   Rango =  161.0
# Variable  hf_score   Rango =  5.360486062
# Variable  hf_rank   Rango =  161.0
# Variable  hf_quartile   Rango =  3.0

# %% [markdown]
# ## 1.2
# Obtener media, mediana y desviación estándar de las variables *pf_identity* y *hf_score* en el mundo y compararla con la de Latinoamérica y el caribe. ¿Tiene sentido calcular la moda?

# %%
# Media pf_identity
print('Valor de la media = {0} en el Mundo para pf_identity.'.format(dataset['pf_identity'].mean()))
print('Valor de la media = {0} en Latino América y el Caribe para pf_identity.'.format(
    dataset[dataset['region'] == 'Latin America & the Caribbean']['pf_identity'].mean()))
# Mediana pf_identity
print('Valor de la mediana = {0} en el Mundo para pf_identity.'.format(dataset['pf_identity'].median()))
print('Valor de la mediana = {0} en Latino América y el Caribe para pf_identity.'.format(
    dataset[dataset['region'] == 'Latin America & the Caribbean']['pf_identity'].median()))
# Desviación Estándar pf_identity
print('Valor de la DS = {0} en el Mundo para pf_identity.'.format(dataset['pf_identity'].std()))
print('Valor de la DS = {0} en Latino América y el Caribe para pf_identity.'.format(
    dataset[dataset['region'] == 'Latin America & the Caribbean']['pf_identity'].std()))
# Media hf_score
print('Valor de la media = {0} en el Mundo para hf_score.'.format(dataset['hf_score'].mean()))
print('Valor de la media = {0} en Latino América y el Caribe para hf_score.'.format(
    dataset[dataset['region'] == 'Latin America & the Caribbean']['hf_score'].mean()))
# Mediana hf_score
print('Valor de la mediana = {0} en el Mundo para hf_score.'.format(dataset['hf_score'].median()))
print('Valor de la mediana = {0} en Latino América y el Caribe para hf_score.'.format(
    dataset[dataset['region'] == 'Latin America & the Caribbean']['hf_score'].median()))
# Desviación Estándar hf_score
print('Valor de la DS = {0} en el Mundo para hf_score.'.format(dataset['hf_score'].std()))
print('Valor de la DS = {0} en Latino América y el Caribe para hf_score.'.format(
    dataset[dataset['region'] == 'Latin America & the Caribbean']['hf_score'].std()))
# Out:
# Valor de la media = 7.33417997096807 en el Mundo para pf_identity.
# Valor de la media = 8.765086206909483 en Latino América y el Caribe para pf_identity.
# Valor de la mediana = 9.166666667000001 en el Mundo para pf_identity.
# Valor de la mediana = 10.0 en Latino América y el Caribe para pf_identity.
# Valor de la DS = 3.159472661477449 en el Mundo para pf_identity.
# Valor de la DS = 1.7117319741534658 en Latino América y el Caribe para pf_identity.
# Valor de la media = 6.9934437555145 en el Mundo para hf_score.
# Valor de la media = 7.047981929952582 en Latino América y el Caribe para hf_score.
# Valor de la mediana = 6.923840432999999 en el Mundo para hf_score.
# Valor de la mediana = 7.02804474 en Latino América y el Caribe para hf_score.
# Valor de la DS = 1.0258111611874141 en el Mundo para hf_score.
# Valor de la DS = 0.6089040915687837 en Latino América y el Caribe para hf_score.

# %%
# ¿Tiene sentido calcular la moda?
# No tiene sentido porque pf_identity y hf_score son variables continuas, entonces es muy posible 
# que ningún valor tenga más ocurrencias que otro.

# %% [markdown]
# ## 1.3
# ¿Son todos los valores de *pf_identity*  y *hf_score* directamente comparables? ¿Qué otra variable podría influenciarlos?

# %%
# Creo que no son directamente comparables. Hay diferencias numéricas entre ambas, se debe considerar lo que se mide
# el valor de la libertad que tiene una perspectiva subjetiva, es decir, la idea de libertad puede ser distinta de un pais a otro.
# ¿Qué otra variable podría influenciarlos?
# Podría influernciarlos el tipo de gobierno, la región, el clima de la región.

# %% [markdown]
# ## 1.4
# ¿Cómo pueden sanearse los valores faltantes?

# %%
# Los valores faltantes podrían completarse tomando como reemplazo la media de la región. Eliminando valores nulos.

# %% [markdown]
# ## 1.5
# ¿Encuentra outliers en estas dos variables? ¿Qué método utiliza para detectarlos? ¿Los outliers, son globales o por grupo? ¿Los eliminaría del conjunto de datos?

# %%
# Outliers de nivel global para pf_identity
dataset.loc[dataset['region'] == 'Latin America & the Caribbean', 'alcance'] = 'Latin America & the Caribbean'
dataset.loc[dataset['region'] != 'Latin America & the Caribbean', 'alcance'] = 'Rest of the world'

plt.figure(figsize=(10,6))
seaborn.boxplot(x="alcance", y="pf_identity", data=dataset, palette="coolwarm")

# %% [markdown]
# ## 2. Agregación de datos

# %% [markdown]
# ## 2.1
# Grafiquen la media de la variable pf_identity y hf_score a través de los años.

# %%
plt.figure(figsize=(17, 4))
seaborn.lineplot(data=dataset, x="year", y="pf_identity", ci=0, label='pf_identity')
seaborn.lineplot(data=dataset, x="year", y="hf_score", ci=0, label='hf_score')
plt.ylabel('Media General')
plt.xlabel('Año')
plt.title('Gráfico de promedios de pf_identity y hf_score por año')
seaborn.despine()

# %% [markdown]
# ## 2.2
# Realicen los mismos gráficos, pero separando por regiones (Cada variable en un gráfico distinto, sino no se ve nada). ¿La tendencia observada, es la misma que si no dividimos por regiones?

# %%
plt.figure(figsize=(17, 10))
seaborn.lineplot(data=dataset, x="year", y="pf_identity", ci=0, hue='region')
plt.ylabel('Media pf_identity')
plt.xlabel('Año')
plt.title('Gráfico de promedios de pf_identity distinguidos por región por año')
seaborn.despine()

plt.figure(figsize=(17, 10))
seaborn.lineplot(data=dataset, x="year", y="hf_score", ci=0, hue='region')
plt.ylabel('Media hf_score')
plt.xlabel('Año')
plt.title('Gráfico de promedios de hf_score distinguidos por región por año')
seaborn.despine()

# %% [markdown]
# ## 2.3
# Si lo consideran necesario, grafiquen algunos países de Latinoamerica para tratar de explicar la tendencia de la variable pf_identity en la región. ¿Cómo seleccionarion los países relevantes a esa tendencia?

# %%
print('Graficos de los mejores 15 registros de promedios de pf_identity por año y país')

dataset_best_reg = dataset.sort_values(by=['pf_identity'], ascending=False)
dataset_best_reg = dataset_best_reg.head(15)

countries = list(dataset_best_reg['countries'].unique())

for country in countries:
  result = dataset[dataset['countries'] == country]['pf_identity']
  result = pandas.Series.tolist(result)
  result = result[8] - result[0]
  if result > 0:
    plt.figure(figsize=(10,4))
    seaborn.lineplot(data=dataset[dataset['countries'] == country], x='year', y='pf_identity', ci=0)
    plt.ylabel('Media pf_identity')
    plt.xlabel('Año')
    plt.title('Gráfico de promedios de pf_identity de ' + country + ' por año')
    seaborn.despine()
    
#Otra forma

#plt.figure(figsize=(17,10))
#seaborn.lineplot(data=dataset_best_reg, x='year', y='pf_identity', hue="countries", ci=0)
#plt.ylabel('Media pf_identity')
#plt.xlabel('Año')
#plt.title('Gráfico de mejores promedios de pf_identity en países por año')
#seaborn.despine()
# Out:
# Graficos de los mejores 15 registros de promedios de pf_identity por año y pa

# %% [markdown]
# ## 3. Distribuciones

# %% [markdown]
# ## 3.1
# Graficar en un mismo histograma la distribución de la variable pf_identity en global, y en Latinoamérica y el caribe. Repetir para la variable hf_score. ¿Visualmente, a qué tipo de distribución corresponde cada variable? ¿Es correcto utilizar todos los registros para esas zonas en estos gráficos?

# %%
plt.figure(figsize=(10,6))
seaborn.distplot(dataset['pf_identity'].dropna(), color=BLUE, label='Global')
seaborn.distplot(dataset[dataset['region'] == 'Latin America & the Caribbean']['pf_identity'].dropna(), color=RED, label='Latinoamérica y el Caribe')
plt.legend()
seaborn.despine()

# %%
# Para pf_identity se observa una distribución normal con asimetría negativa tanto para Global, Latinomamérica y Caribe. 
# Se puede observar que la mayor concentración de los datos está más próximo de lo que sería el rango máximo.
# Para hf_score se observa tanto para Global, Latinoamérica y Caribe una distribución que se asemeja a una normal, 
# sobre para el segundo caso. A nivel Global es relativamente notorio la presencia de dos picos ubicados entre 6.5 y 8.5.

# %% [markdown]
# ## 3.2
# Realizar una prueba de Kolmogorov-Smirnof para comprobar analíticamente si estas variables responden la distribución propuesta en el ejercicio anterior. Hint: podés usar https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.kstest.html, pero hay que tener en cuenta que si la distribución es "norm", entonces va a comparar los datos con una distribución normal con media 0 y desviación estándar 1. Se puede utilizar la distribución sobre todos los datos o sólo sobre Latinoamérica.

# %%
# Normalizamos para pf_identity
mean_pf, std_pf = ss.norm.fit(dataset['pf_identity'].dropna())
norm_pf = (dataset['pf_identity'].dropna() - mean_pf) / std_pf

# Normalizamos para hf_score
mean_hf, std_hf = ss.norm.fit(dataset['hf_score'].dropna())
norm_hf = (dataset['hf_score'].dropna() - mean_hf) / std_hf

# Obtenemos los indicadores para pf_identity
kstest_pf = ss.kstest(numpy.array(norm_pf), 'norm')

# Obtenemos los indicadores para hf_score
kstest_hf = ss.kstest(numpy.array(norm_hf), 'norm')

print('pvalue_pf', kstest_pf, ' - pvalue_hf', kstest_hf)
# Out:
# pvalue_pf KstestResult(statistic=0.2368216885475004, pvalue=1.7837097494493251e-68)  - pvalue_hf KstestResult(statistic=0.06606589707833843, pvalue=1.1309978419994058e-05)

# %%
## Dado que para ambas variables los pvalue son próximos a cero no podemos aseverar 
## que las distribuciones en ambos casos sean normales.

# %% [markdown]
# ## 3.3
# Realizar un gráfico QQ de las mismas distribuciones. Se puede utilizar a,bas distribuciones sobre todos los datos o sólo sobre Latinoamérica, pero no cruzadas.

# %%
percs = numpy.linspace(0,100,21)  # Creamos 20 puntos percentiles igualmente distribuidos entre 0 y 100.
qn_pf_identity = numpy.percentile(dataset['pf_identity'].dropna(), percs)
qn_hf_score = numpy.percentile(dataset['hf_score'].dropna(), percs)
plt.figure(figsize=(12,6))
seaborn.regplot(x=qn_pf_identity, y=qn_hf_score)
plt.xlabel('Percentiles de pf_identity a nivel Global')
plt.ylabel('Percentiles de pf_identity a nivel Global')

# Graficamos la linea de la identidad.
x = numpy.linspace(numpy.min((qn_pf_identity.min(),qn_hf_score.min())), numpy.max((qn_pf_identity.max(),qn_hf_score.max())))
plt.plot(x,x, color=RED, ls="--")

seaborn.despine()

# %%
## El gráfico muestra una correlación lineal entre ambas distribuciones pero no lo suficiente para decir que son iguales.

# %% [markdown]
# ## 3.4
# Medir la asimetría (skew) y curtosis de las mismas distribuciones con las que realizó el gráfico anterior. ¿Cómo se relacionan estos estadísticos con la forma del gráfico QQ obtenido previamente? ¿El gráfico QQ provee más información que no esté presente en estos estadísticos?

# %%
# Valor de asimetría pf_identity nivel Global
skew_pf_identity = ss.skew(dataset['pf_identity'].dropna())
# Valor de asimetría hf_score nivel Global
skew_hf_score = ss.skew(dataset['hf_score'].dropna())
# Valor de curtosis pf_identity nivel Global
kurt_pf_identity = ss.kurtosis(dataset['pf_identity'].dropna())
# Valor de curtosis hf_score nivel Global 
kurt_hf_score = ss.kurtosis(dataset['hf_score'].dropna())

print('Asimetría para pf_identity = {0}'.format(skew_pf_identity))
print('Asimetría para hf_score = {0}'.format(skew_hf_score))
print('Curtosis para pf_identity = {0}'.format(kurt_pf_identity))
print('Curtosis para hf_score = {0}'.format(kurt_hf_score))
# Out:
# Asimetría para pf_identity = -0.9121780542847563
# Asimetría para hf_score = -0.21205190437691196
# Curtosis para pf_identity = -0.4148322234251629
# Curtosis para hf_score = -0.5101904315124792

# %%
# Un valor negativo para la asimetría indica una distribución alargada hacia la izquierda, 
# hacia valores menores a la media. Esto se observa para ambas (pf_identity y hf_score).
# El valor negativo para la curtosis indica una distribución algo aplanada, esto significa una mayor dispersión de los datos 
# respecto de la media. Esto se observa para ambas (pf_identity y hf_score).

# %% [markdown]
# ## 4. Correlaciones

# %% [markdown]
# ## 4.1
# ¿Qué conclusiones puede sacar de un gráfico pairplot de estas tres variables? ¿Es adecuado para los valores de pf_identity? ¿Por qué?

# %% [markdown]
# ## 4.2
# Graficar la correlación entre pf_identity y hf_score; y entre pf_identity y ef_score. Analizar el resultado, ¿se pueden sacar conclusiones? Tengan en cuenta que como pf_identity es el resultado de un promedio, sólo toma algunos valores. Es, en efecto, discreta.

# %% [markdown]
# ## 4.3
# Calcular algún coeficiente de correlación adecuado entre los dos pares de variables, dependiendo de la cantidad de datos, el tipo de datos y la distribución de los mismo. Algunas opciones son: coeficiente de pearson, coeficiente de spearman, coeficientes de tau y de kendall. Interpretar los resultados y justificar si las variables están correlacionadas o no.

# %% [markdown]
# ## 4.4
# [Opcional] Analizar la correlación entre la region y el hf_score (y/o el ef_score); y entre la region y el pf_identity. Considerar que como la variable region es ordinal, debe utilizarse algún tipo de test. Explicar cuáles son los requisitos necesarios para la aplicación de ese test. (Si no se cumplieran, se pueden agregar algunos datos para generar más registros)
